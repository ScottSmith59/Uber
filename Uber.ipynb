# %%
import pandas as pd
import numpy as np
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
% matplotlib inline

df_uber = pd.read_csv('Uber.csv')

# %%
df_uber.head()
# Out:
#    Time   Time.1    Miles     Cost          Date  Unnamed: 5  Total  \
# 0   636  6:36 AM  0.00 mi   $3.75   Friday May 4         NaN    NaN
# 1   641  6:41 AM  9.17 mi  $10.35   Friday May 4         NaN    NaN
# 2   720  7:20 AM  4.23 mi   $4.24   Friday May 4         NaN    NaN
# 3   742  7:42 AM  2.24 mi   $3.91   Friday May 4         NaN    NaN
# 4   800  8:00 AM  4.22 mi   $4.65   Friday May 4         NaN    NaN
#
#                                    Beginning Route  \
# 0                                              NaN
# 1  1085 Highland Oaks Dr, Southlake, TX 76092, USA
# 2    385 E Las Colinas Blvd, Irving, TX 75039, USA
# 3                                              NaN
# 4                                              NaN
#
#                                            End Route
# 0                                                NaN
# 1  2400 Aviation Dr, DFW Airport, TX 75261, Unite...
# 2         5931 Campus Circle Dr W, Irving, 75063, US
# ...

# %%
df_uber.shape
# Out:
# (913, 9)

# %%
df_uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913 entries, 0 to 912
# Data columns (total 9 columns):
# Time               913 non-null int64
# Time.1             913 non-null object
# Miles              913 non-null object
# Cost               913 non-null object
# Date               913 non-null object
# Unnamed: 5         0 non-null float64
# Total              0 non-null float64
# Beginning Route    2 non-null object
# End Route          2 non-null object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 42.8+ KB

# %%
df_uber.describe()
# Out:
#               Time  Unnamed: 5  Total
# count   913.000000         0.0    0.0
# mean   1168.536692         NaN    NaN
# std     328.023261         NaN    NaN
# min     630.000000         NaN    NaN
# 25%     857.000000         NaN    NaN
# 50%    1151.000000         NaN    NaN
# 75%    1434.000000         NaN    NaN
# max    1929.000000         NaN    NaN

# %%
df_uber_clean = df_uber.copy()

# %%
df_uber_clean
# Out:
#      Time    Time.1     Miles     Cost          Date  Unnamed: 5  Total  \
# 0     636   6:36 AM   0.00 mi   $3.75   Friday May 4         NaN    NaN
# 1     641   6:41 AM   9.17 mi  $10.35   Friday May 4         NaN    NaN
# 2     720   7:20 AM   4.23 mi   $4.24   Friday May 4         NaN    NaN
# 3     742   7:42 AM   2.24 mi   $3.91   Friday May 4         NaN    NaN
# 4     800   8:00 AM   4.22 mi   $4.65   Friday May 4         NaN    NaN
# 5     814   8:14 AM   3.64 mi   $3.97   Friday May 4         NaN    NaN
# 6     835   8:35 AM  10.33 mi   $9.40   Friday May 4         NaN    NaN
# 7     905   9:05 AM   4.51 mi  $16.28   Friday May 4         NaN    NaN
# 8     919   9:19 AM   3.23 mi   $9.21   Friday May 4         NaN    NaN
# 9     945   9:45 AM  18.91 mi  $18.75   Friday May 4         NaN    NaN
# 10   1030  10:30 AM   1.08 mi   $6.27   Friday May 4         NaN    NaN
# 11   1040  10:40 AM  27.09 mi  $38.86   Friday May 4         NaN    NaN
# ...

# %%
df_uber_clean.rename(columns = {'Cost':'Wages'}, inplace = True)

# %%
df_uber_clean = df_uber_clean.drop('Time.1', axis=1)

# %%
df_uber_clean.head()
# Out:
#    Time    Miles    Wages          Date  Unnamed: 5  Total  \
# 0   636  0.00 mi   $3.75   Friday May 4         NaN    NaN
# 1   641  9.17 mi  $10.35   Friday May 4         NaN    NaN
# 2   720  4.23 mi   $4.24   Friday May 4         NaN    NaN
# 3   742  2.24 mi   $3.91   Friday May 4         NaN    NaN
# 4   800  4.22 mi   $4.65   Friday May 4         NaN    NaN
#
#                                    Beginning Route  \
# 0                                              NaN
# 1  1085 Highland Oaks Dr, Southlake, TX 76092, USA
# 2    385 E Las Colinas Blvd, Irving, TX 75039, USA
# 3                                              NaN
# 4                                              NaN
#
#                                            End Route
# 0                                                NaN
# 1  2400 Aviation Dr, DFW Airport, TX 75261, Unite...
# 2         5931 Campus Circle Dr W, Irving, 75063, US
# 3                                                NaN
# ...

# %%
df_uber_clean = df_uber_clean.drop('Unnamed: 5', axis=1)

# %%
df_uber_clean = df_uber_clean.drop('Total', axis=1)

# %%
df_uber_clean.head()
# Out:
#    Time    Miles    Wages          Date  \
# 0   636  0.00 mi   $3.75   Friday May 4
# 1   641  9.17 mi  $10.35   Friday May 4
# 2   720  4.23 mi   $4.24   Friday May 4
# 3   742  2.24 mi   $3.91   Friday May 4
# 4   800  4.22 mi   $4.65   Friday May 4
#
#                                    Beginning Route  \
# 0                                              NaN
# 1  1085 Highland Oaks Dr, Southlake, TX 76092, USA
# 2    385 E Las Colinas Blvd, Irving, TX 75039, USA
# 3                                              NaN
# 4                                              NaN
#
#                                            End Route
# 0                                                NaN
# 1  2400 Aviation Dr, DFW Airport, TX 75261, Unite...
# 2         5931 Campus Circle Dr W, Irving, 75063, US
# 3                                                NaN
# 4                                                NaN

# %%
df_uber_clean.Miles = df_uber_clean.Miles.str[:-3]

# %%
df_uber_clean.tail()
# Out:
#      Time Miles    Wages        Date Beginning Route End Route
# 908  1458  9.99  $10.56   Tue Aug 21             NaN       NaN
# 909  1518  8.32  $14.44   Tue Aug 21             NaN       NaN
# 910  1734  2.98   $5.86   Tue Aug 21             NaN       NaN
# 911  1802  3.41   $4.52   Tue Aug 21             NaN       NaN
# 912  1840  6.36   $7.67   Tue Aug 21             NaN       NaN

# %%
df_uber_clean.Miles = df_uber_clean.Miles.astype(float)

# %%
df_uber_clean.at[912, "Wages"] = '$7.67'

# %%
df_uber_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913 entries, 0 to 912
# Data columns (total 6 columns):
# Time               913 non-null int64
# Miles              913 non-null float64
# Wages              913 non-null object
# Date               913 non-null object
# Beginning Route    2 non-null object
# End Route          2 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 28.6+ KB

# %%
df_uber_clean['Day'], df_uber_clean['Dates'] = df_uber_clean['Date'].str.split(' ', 1).str

# %%
df_uber_clean.head()
# Out:
#    Time  Miles    Wages          Date  \
# 0   636   0.00   $3.75   Friday May 4
# 1   641   9.17  $10.35   Friday May 4
# 2   720   4.23   $4.24   Friday May 4
# 3   742   2.24   $3.91   Friday May 4
# 4   800   4.22   $4.65   Friday May 4
#
#                                    Beginning Route  \
# 0                                              NaN
# 1  1085 Highland Oaks Dr, Southlake, TX 76092, USA
# 2    385 E Las Colinas Blvd, Irving, TX 75039, USA
# 3                                              NaN
# 4                                              NaN
#
#                                            End Route     Day  Dates
# 0                                                NaN  Friday  May 4
# 1  2400 Aviation Dr, DFW Airport, TX 75261, Unite...  Friday  May 4
# 2         5931 Campus Circle Dr W, Irving, 75063, US  Friday  May 4
# 3                                                NaN  Friday  May 4
# 4                                                NaN  Friday  May 4

# %%
df_uber_clean = df_uber_clean.drop('Date', axis=1)

# %%
df_uber_clean.head()
# Out:
#    Time  Miles    Wages                                  Beginning Route  \
# 0   636   0.00   $3.75                                               NaN
# 1   641   9.17  $10.35   1085 Highland Oaks Dr, Southlake, TX 76092, USA
# 2   720   4.23   $4.24     385 E Las Colinas Blvd, Irving, TX 75039, USA
# 3   742   2.24   $3.91                                               NaN
# 4   800   4.22   $4.65                                               NaN
#
#                                            End Route     Day  Dates
# 0                                                NaN  Friday  May 4
# 1  2400 Aviation Dr, DFW Airport, TX 75261, Unite...  Friday  May 4
# 2         5931 Campus Circle Dr W, Irving, 75063, US  Friday  May 4
# 3                                                NaN  Friday  May 4
# 4                                                NaN  Friday  May 4

# %%
df_uber_clean = df_uber_clean[['Day', 'Dates', 'Time', 'Miles', 'Wages', 'Beginning Route', 'End Route']]

# %%
df_uber_clean.Wages = df_uber_clean.Wages.str[1:]

# %%
df_uber_clean.head()
# Out:
#       Day  Dates  Time  Miles   Wages  \
# 0  Friday  May 4   636   0.00   3.75
# 1  Friday  May 4   641   9.17  10.35
# 2  Friday  May 4   720   4.23   4.24
# 3  Friday  May 4   742   2.24   3.91
# 4  Friday  May 4   800   4.22   4.65
#
#                                    Beginning Route  \
# 0                                              NaN
# 1  1085 Highland Oaks Dr, Southlake, TX 76092, USA
# 2    385 E Las Colinas Blvd, Irving, TX 75039, USA
# 3                                              NaN
# 4                                              NaN
#
#                                            End Route
# 0                                                NaN
# 1  2400 Aviation Dr, DFW Airport, TX 75261, Unite...
# 2         5931 Campus Circle Dr W, Irving, 75063, US
# 3                                                NaN
# 4                                                NaN

# %%
df_uber_clean.Wages = df_uber_clean.Wages.astype(float)

# %%
df_uber_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913 entries, 0 to 912
# Data columns (total 7 columns):
# Day                913 non-null object
# Dates              913 non-null object
# Time               913 non-null int64
# Miles              913 non-null float64
# Wages              913 non-null float64
# Beginning Route    2 non-null object
# End Route          2 non-null object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 35.7+ KB

# %%
df_uber_clean['WkDay'] = df_uber_clean['Day'].str[:3]

# %%
df_uber_clean.head()
# Out:
#       Day  Dates  Time  Miles  Wages  \
# 0  Friday  May 4   636   0.00   3.75
# 1  Friday  May 4   641   9.17  10.35
# 2  Friday  May 4   720   4.23   4.24
# 3  Friday  May 4   742   2.24   3.91
# 4  Friday  May 4   800   4.22   4.65
#
#                                    Beginning Route  \
# 0                                              NaN
# 1  1085 Highland Oaks Dr, Southlake, TX 76092, USA
# 2    385 E Las Colinas Blvd, Irving, TX 75039, USA
# 3                                              NaN
# 4                                              NaN
#
#                                            End Route WkDay
# 0                                                NaN   Fri
# 1  2400 Aviation Dr, DFW Airport, TX 75261, Unite...   Fri
# 2         5931 Campus Circle Dr W, Irving, 75063, US   Fri
# 3                                                NaN   Fri
# 4                                                NaN   Fri

# %%
df_uber_clean = df_uber_clean.drop('Day', axis=1)

# %%
df_uber_clean.head()
# Out:
#    Dates  Time  Miles  Wages                                  Beginning Route  \
# 0  May 4   636   0.00   3.75                                              NaN
# 1  May 4   641   9.17  10.35  1085 Highland Oaks Dr, Southlake, TX 76092, USA
# 2  May 4   720   4.23   4.24    385 E Las Colinas Blvd, Irving, TX 75039, USA
# 3  May 4   742   2.24   3.91                                              NaN
# 4  May 4   800   4.22   4.65                                              NaN
#
#                                            End Route WkDay
# 0                                                NaN   Fri
# 1  2400 Aviation Dr, DFW Airport, TX 75261, Unite...   Fri
# 2         5931 Campus Circle Dr W, Irving, 75063, US   Fri
# 3                                                NaN   Fri
# 4                                                NaN   Fri

# %%
df_uber_clean = df_uber_clean[['WkDay', 'Dates', 'Time', 'Miles', 'Wages', 'Beginning Route', 'End Route']]

# %%
df_uber_clean.head()
# Out:
#   WkDay  Dates  Time  Miles  Wages  \
# 0   Fri  May 4   636   0.00   3.75
# 1   Fri  May 4   641   9.17  10.35
# 2   Fri  May 4   720   4.23   4.24
# 3   Fri  May 4   742   2.24   3.91
# 4   Fri  May 4   800   4.22   4.65
#
#                                    Beginning Route  \
# 0                                              NaN
# 1  1085 Highland Oaks Dr, Southlake, TX 76092, USA
# 2    385 E Las Colinas Blvd, Irving, TX 75039, USA
# 3                                              NaN
# 4                                              NaN
#
#                                            End Route
# 0                                                NaN
# 1  2400 Aviation Dr, DFW Airport, TX 75261, Unite...
# 2         5931 Campus Circle Dr W, Irving, 75063, US
# 3                                                NaN
# 4                                                NaN

# %%
#df_uber_clean.loc[df_uber_clean['Beginning Route'].isna(), 'Beginning Route'] == 'none'
#df_uber_clean.loc[df_uber_clean['Beginning Route'] == '', 'Beginning Route'] = df_uber_clean.loc[df_uber_clean['Beginning Route'] == '', 'Beginning Route'].fillna('none')

# %%
df_uber_clean.mean()
# Out:
# Time     1168.536692
# Miles       9.078248
# Wages      10.160515
# dtype: float64

# %%
plt.figure(figsize=(15, 9))
plt.scatter(data = df_uber_clean, x = 'Miles', y = 'Wages')
plt.xlabel('Miles', fontsize = 18)
plt.ylabel('Wages', fontsize = 18);

# %%
df_day = df_uber_clean.groupby(['WkDay'], as_index = False)['Wages'].mean()
#df_day = df_uber_clean.groupby(['WkDay', "Time"], as_index = False)['Wages'].mean()

# %%
df_day
# Out:
#   WkDay      Wages
# 0   Fri   9.437606
# 1   Mon  10.289939
# 2   Thu  10.858503
# 3   Tue  10.396000
# 4   Wed   9.784118

# %%
df_time_m = df_uber_clean[df_uber_clean['Time'] <= 1000]

# %%
df_time_m
# Out:
#     WkDay   Dates  Time  Miles  Wages  \
# 0     Fri   May 4   636   0.00   3.75
# 1     Fri   May 4   641   9.17  10.35
# 2     Fri   May 4   720   4.23   4.24
# 3     Fri   May 4   742   2.24   3.91
# 4     Fri   May 4   800   4.22   4.65
# 5     Fri   May 4   814   3.64   3.97
# 6     Fri   May 4   835  10.33   9.40
# 7     Fri   May 4   905   4.51  16.28
# 8     Fri   May 4   919   3.23   9.21
# 9     Fri   May 4   945  18.91  18.75
# 22    Mon   May 7   637  42.47  47.68
# 23    Mon   May 7   803  10.95   9.64
# 24    Mon   May 7   836   3.96   4.10
# 25    Mon   May 7   900   0.00   3.75
# 26    Mon   May 7   914   9.70  13.47
# 27    Mon   May 7   932  26.20  25.73
# 38    Tue   May 8   633  21.30  21.42
# 39    Tue   May 8   725   7.60   8.95
# 40    Tue   May 8   756   0.50   4.85
# 41    Tue   May 8   807  10.34  11.49
# 42    Tue   May 8   830  20.49  24.54
# 43    Tue   May 8   920  13.32  16.39
# 49    Wed   May 9   707  24.23  19.85
# ...

# %%
mask = df_uber_clean['Time'] <= 1000
df_time_m = df_uber_clean[mask]
df_time_m
# Out:
#     WkDay   Dates  Time  Miles  Wages  \
# 0     Fri   May 4   636   0.00   3.75
# 1     Fri   May 4   641   9.17  10.35
# 2     Fri   May 4   720   4.23   4.24
# 3     Fri   May 4   742   2.24   3.91
# 4     Fri   May 4   800   4.22   4.65
# 5     Fri   May 4   814   3.64   3.97
# 6     Fri   May 4   835  10.33   9.40
# 7     Fri   May 4   905   4.51  16.28
# 8     Fri   May 4   919   3.23   9.21
# 9     Fri   May 4   945  18.91  18.75
# 22    Mon   May 7   637  42.47  47.68
# 23    Mon   May 7   803  10.95   9.64
# 24    Mon   May 7   836   3.96   4.10
# 25    Mon   May 7   900   0.00   3.75
# 26    Mon   May 7   914   9.70  13.47
# 27    Mon   May 7   932  26.20  25.73
# 38    Tue   May 8   633  21.30  21.42
# 39    Tue   May 8   725   7.60   8.95
# 40    Tue   May 8   756   0.50   4.85
# 41    Tue   May 8   807  10.34  11.49
# 42    Tue   May 8   830  20.49  24.54
# 43    Tue   May 8   920  13.32  16.39
# 49    Wed   May 9   707  24.23  19.85
# ...

# %%
df_time_m.Wages.mean()
# Out:
# 9.886809815950912

# %%
df_time_m.WkDay.value_counts()
# Out:
# Tue    79
# Fri    74
# Thu    65
# Wed    55
# Mon    53
# Name: WkDay, dtype: int64

# %%
df_time_m['Dates'].describe()
# Out:
# count        326
# unique        56
# top       Jul 10
# freq          10
# Name: Dates, dtype: object

# %%
df_time_a = df_uber_clean[df_uber_clean['Time'] > 1400]

# %%
mask = df_uber_clean['Time'] > 1400
df_time_a = df_uber_clean[mask]
df_time_a
# Out:
#     WkDay   Dates  Time  Miles  Wages Beginning Route End Route
# 19    Fri   May 4  1410   2.87   3.34             NaN       NaN
# 20    Fri   May 4  1434   5.41   6.40             NaN       NaN
# 21    Fri   May 4  1510  21.74  25.23             NaN       NaN
# 36    Mon   May 7  1423  18.68  17.54             NaN       NaN
# 37    Mon   May 7  1501   5.25   5.50             NaN       NaN
# 63    Wed   May 9  1401  25.54  20.68             NaN       NaN
# 64    Wed   May 9  1442   3.23   3.83             NaN       NaN
# 65    Wed   May 9  1457   1.56   3.70             NaN       NaN
# 66    Wed   May 9  1627   1.48   2.85             NaN       NaN
# 67    Wed   May 9  1642   7.01   6.31             NaN       NaN
# 68    Wed   May 9  1710  15.60  13.48             NaN       NaN
# 79    Thu  May 10  1411  12.50  16.48             NaN       NaN
# 80    Thu  May 10  1449  11.76  11.97             NaN       NaN
# 95    Fri  May 11  1422   5.62   5.56             NaN       NaN
# ...

# %%
df_time_a.Wages.mean()
# Out:
# 10.062072727272716

# %%
df_time_a.WkDay.value_counts()
# Out:
# Tue    62
# Thu    61
# Wed    56
# Mon    55
# Fri    41
# Name: WkDay, dtype: int64

# %%
df_time_l = df_uber_clean[(df_uber_clean.Time > 1000) & (df_uber_clean.Time <= 1400)]

# %%
df_time_l
# Out:
#     WkDay   Dates  Time  Miles  Wages Beginning Route End Route
# 10    Fri   May 4  1030   1.08   6.27             NaN       NaN
# 11    Fri   May 4  1040  27.09  38.86             NaN       NaN
# 12    Fri   May 4  1128   6.56   8.15             NaN       NaN
# 13    Fri   May 4  1210   9.60  12.46             NaN       NaN
# 14    Fri   May 4  1239   1.04   2.85             NaN       NaN
# 15    Fri   May 4  1249   1.28   4.85             NaN       NaN
# 16    Fri   May 4  1300   4.58   4.73             NaN       NaN
# 17    Fri   May 4  1317  19.08  16.75             NaN       NaN
# 18    Fri   May 4  1352   6.02   8.40             NaN       NaN
# 28    Mon   May 7  1019   3.01   3.55             NaN       NaN
# 29    Mon   May 7  1102  12.12  13.12             NaN       NaN
# 30    Mon   May 7  1127   4.90   4.68             NaN       NaN
# 31    Mon   May 7  1142  33.45  31.88             NaN       NaN
# 32    Mon   May 7  1237   3.11   3.57             NaN       NaN
# ...

# %%
df_time_mor = df_uber_clean.query('Time < 1000')

# %%
df_time_mor
# Out:
#     WkDay   Dates  Time  Miles  Wages  \
# 0     Fri   May 4   636   0.00   3.75
# 1     Fri   May 4   641   9.17  10.35
# 2     Fri   May 4   720   4.23   4.24
# 3     Fri   May 4   742   2.24   3.91
# 4     Fri   May 4   800   4.22   4.65
# 5     Fri   May 4   814   3.64   3.97
# 6     Fri   May 4   835  10.33   9.40
# 7     Fri   May 4   905   4.51  16.28
# 8     Fri   May 4   919   3.23   9.21
# 9     Fri   May 4   945  18.91  18.75
# 22    Mon   May 7   637  42.47  47.68
# 23    Mon   May 7   803  10.95   9.64
# 24    Mon   May 7   836   3.96   4.10
# 25    Mon   May 7   900   0.00   3.75
# 26    Mon   May 7   914   9.70  13.47
# 27    Mon   May 7   932  26.20  25.73
# 38    Tue   May 8   633  21.30  21.42
# 39    Tue   May 8   725   7.60   8.95
# 40    Tue   May 8   756   0.50   4.85
# 41    Tue   May 8   807  10.34  11.49
# 42    Tue   May 8   830  20.49  24.54
# 43    Tue   May 8   920  13.32  16.39
# 49    Wed   May 9   707  24.23  19.85
# ...

# %%
df_time_aft = df_uber_clean.query('Time > 1300')

# %%
df_time_aft
# Out:
#     WkDay   Dates  Time  Miles  Wages Beginning Route End Route
# 17    Fri   May 4  1317  19.08  16.75             NaN       NaN
# 18    Fri   May 4  1352   6.02   8.40             NaN       NaN
# 19    Fri   May 4  1410   2.87   3.34             NaN       NaN
# 20    Fri   May 4  1434   5.41   6.40             NaN       NaN
# 21    Fri   May 4  1510  21.74  25.23             NaN       NaN
# 34    Mon   May 7  1308   3.40   3.73             NaN       NaN
# 35    Mon   May 7  1324  35.99  34.81             NaN       NaN
# 36    Mon   May 7  1423  18.68  17.54             NaN       NaN
# 37    Mon   May 7  1501   5.25   5.50             NaN       NaN
# 61    Wed   May 9  1305  10.80  16.37             NaN       NaN
# 62    Wed   May 9  1328  21.14  19.52             NaN       NaN
# 63    Wed   May 9  1401  25.54  20.68             NaN       NaN
# 64    Wed   May 9  1442   3.23   3.83             NaN       NaN
# 65    Wed   May 9  1457   1.56   3.70             NaN       NaN
# ...

# %%
df_time_lun = df_uber_clean.query('Time > 1000 & Time <= 1300')

# %%
df_time_lun
# Out:
#     WkDay   Dates  Time  Miles  Wages Beginning Route End Route
# 10    Fri   May 4  1030   1.08   6.27             NaN       NaN
# 11    Fri   May 4  1040  27.09  38.86             NaN       NaN
# 12    Fri   May 4  1128   6.56   8.15             NaN       NaN
# 13    Fri   May 4  1210   9.60  12.46             NaN       NaN
# 14    Fri   May 4  1239   1.04   2.85             NaN       NaN
# 15    Fri   May 4  1249   1.28   4.85             NaN       NaN
# 16    Fri   May 4  1300   4.58   4.73             NaN       NaN
# 28    Mon   May 7  1019   3.01   3.55             NaN       NaN
# 29    Mon   May 7  1102  12.12  13.12             NaN       NaN
# 30    Mon   May 7  1127   4.90   4.68             NaN       NaN
# 31    Mon   May 7  1142  33.45  31.88             NaN       NaN
# 32    Mon   May 7  1237   3.11   3.57             NaN       NaN
# 33    Mon   May 7  1257   3.84   4.02             NaN       NaN
# 44    Tue   May 8  1039   3.53   6.03             NaN       NaN
# ...

# %%
print(df_time_mor.Wages.mean())
print(df_time_lun.Wages.mean())
print(df_time_aft.Wages.mean())
# Out:
# 9.929907407407399
# 10.18800847457626
# 10.396239316239313

# %%
print(df_time_mor.WkDay.value_counts())
print(df_time_lun.WkDay.value_counts())
print(df_time_aft.WkDay.value_counts())
# Out:
# Tue    79
# Fri    74
# Thu    65
# Wed    54
# Mon    52
# Name: WkDay, dtype: int64
# Fri    55
# Tue    49
# Thu    47
# Wed    44
# Mon    41
# Name: WkDay, dtype: int64
# Tue    77
# Thu    75
# Wed    71
# Mon    69
# Fri    59
# Name: WkDay, dtype: int64

# %%
print(df_time_mor.groupby(['WkDay'], as_index = False)['Wages'].mean())
print(df_time_lun.groupby(['WkDay'], as_index = False)['Wages'].mean())
print(df_time_aft.groupby(['WkDay'], as_index = False)['Wages'].mean())
print(df_time_mor.groupby(['WkDay'], as_index = False)['Wages'].max())
print(df_time_lun.groupby(['WkDay'], as_index = False)['Wages'].max())
print(df_time_aft.groupby(['WkDay'], as_index = False)['Wages'].max())
# Out:
#   WkDay      Wages
# 0   Fri   8.937162
# 1   Mon  11.851923
# 2   Thu  10.570308
# 3   Tue   9.857848
# 4   Wed   8.774074
#   WkDay      Wages
# 0   Fri   9.449818
# 1   Mon  10.146098
# 2   Thu  11.049362
# 3   Tue  11.422041
# 4   Wed   8.855455
#   WkDay      Wages
# 0   Fri  10.053898
# 1   Mon   9.305507
# 2   Thu  10.988667
# 3   Tue  10.295195
# 4   Wed  11.224507
#   WkDay  Wages
# 0   Fri  43.01
# 1   Mon  47.68
# 2   Thu  48.01
# 3   Tue  30.07
# 4   Wed  28.42
#   WkDay  Wages
# 0   Fri  38.86
# 1   Mon  34.00
# 2   Thu  40.07
# 3   Tue  42.81
# 4   Wed  30.85
#   WkDay  Wages
# 0   Fri  68.14
# 1   Mon  34.81
# 2   Thu  28.86
# 3   Tue  29.77
# 4   Wed  34.82

# %%
base_color = sns.color_palette()[0]
plt.figure(figsize=[15, 9])
df_time_mor.groupby(['WkDay'], as_index = False)['Wages'].mean()
sns.countplot(data = df_time_mor, x = 'WkDay', color = base_color)
plt.title('Average Wages per Morning Ride')
plt.ylabel('Wages')
plt.xlabel('Weekday');

# %%
df_time_mor.groupby(['WkDay'], as_index = False)['Wages'].mean().plot(kind = 'bar', title = 'Average Wages per Morning Ride')
plt.xlabel('Weekday')
plt.ylabel('Wages');
plt.xticks([0, 1, 2, 3, 4], ['Fri', 'Mon', 'Thu', 'Tue', 'Wed']);

# %%
base_color = sns.color_palette()[0]
plt.figure(figsize=[15, 9])
df_time_lun.groupby(['WkDay'], as_index = False)['Wages'].mean()
sns.countplot(data = df_time_mor, x = 'WkDay', color = base_color)
plt.title('Average Wages per Lunchtime Ride')
plt.ylabel('Wages')
plt.xlabel('Weekday');

# %%
base_color = sns.color_palette()[0]
plt.figure(figsize=[15, 9])
df_time_aft.groupby(['WkDay'], as_index = False)['Wages'].mean()
sns.countplot(data = df_time_mor, x = 'WkDay', color = base_color)
plt.title('Average Wages per Afternoon Ride')
plt.ylabel('Wages')
plt.xlabel('Weekday');

# %%
print(df_time_mor.Wages.sum())
print(df_time_lun.Wages.sum())
print(df_time_aft.Wages.sum())
# Out:
# 3217.29
# 2404.37
# 3649.08

# %%
print(df_time_mor.groupby(['WkDay'], as_index = True).Wages.sum())
print(df_time_lun.groupby(['WkDay'], as_index = True).Wages.sum())
print(df_time_aft.groupby(['WkDay'], as_index = True).Wages.sum())
# Out:
# WkDay
# Fri    661.35
# Mon    616.30
# Thu    687.07
# Tue    778.77
# Wed    473.80
# Name: Wages, dtype: float64
# WkDay
# Fri    519.74
# Mon    415.99
# Thu    519.32
# Tue    559.68
# Wed    389.64
# Name: Wages, dtype: float64
# WkDay
# Fri    593.18
# Mon    642.08
# Thu    824.15
# Tue    792.73
# Wed    796.94
# Name: Wages, dtype: float64

# %%
df_mor_total = df_time_mor.groupby(['WkDay'], as_index = True).Wages.sum()
df_lun_total = df_time_lun.groupby(['WkDay'], as_index = True).Wages.sum()
df_aft_total = df_time_aft.groupby(['WkDay'], as_index = True).Wages.sum()

# %%
df_mor_ave = df_time_mor.groupby(['WkDay'], as_index = True).Wages.count()
df_lun_ave = df_time_lun.groupby(['WkDay'], as_index = True).Wages.count()
df_aft_ave = df_time_aft.groupby(['WkDay'], as_index = True).Wages.count()

# %%
print(df_mor_ave)
print(df_lun_ave)
print(df_aft_ave)
# Out:
# WkDay
# Fri    74
# Mon    52
# Thu    65
# Tue    79
# Wed    54
# Name: Wages, dtype: int64
# WkDay
# Fri    55
# Mon    41
# Thu    47
# Tue    49
# Wed    44
# Name: Wages, dtype: int64
# WkDay
# Fri    59
# Mon    69
# Thu    75
# Tue    77
# Wed    71
# Name: Wages, dtype: int64

# %%
print(df_mor_total / df_mor_ave)
print(df_lun_total / df_lun_ave)
print(df_aft_total / df_aft_ave)
# Out:
# WkDay
# Fri     8.937162
# Mon    11.851923
# Thu    10.570308
# Tue     9.857848
# Wed     8.774074
# Name: Wages, dtype: float64
# WkDay
# Fri     9.449818
# Mon    10.146098
# Thu    11.049362
# Tue    11.422041
# Wed     8.855455
# Name: Wages, dtype: float64
# WkDay
# Fri    10.053898
# Mon     9.305507
# Thu    10.988667
# Tue    10.295195
# Wed    11.224507
# Name: Wages, dtype: float64

# %%
df_mor_total = df_time_mor.groupby(['WkDay == Fri'], as_index = True).Wages.sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-161-d3e9b1b12a9d> in <module>()
# ----> 1 df_mor_total = df_time_mor.groupby(['WkDay == Fri'], as_index = True).Wages.sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
# ...

# %%
print(df_time_mor.Dates.value_counts())
# Out:
# Jul 24     10
# Jul 10     10
# May 4      10
# Jul 11      9
# May 11      9
# May 23      8
# Jun 20      8
# May 21      8
# May 18      8
# June 19     7
# Jun 5       7
# Jun 21      7
# May 31      7
# May 14      7
# Jun 28      6
# Jun 1       6
# Aug 16      6
# May 16      6
# Aug 21      6
# May 7       6
# Aug 9       6
# Jul 31      6
# May 25      6
# May 9       6
# May 15      6
# Jul 13      6
# Jul 2       6
# May 22      6
# May 8       6
# May 17      6
# Jun 7       6
# Jun 29      6
# Aug 13      6
# June 26     5
# Aug 20      5
# Aug 10      5
# Jun 22      5
# Jul 12      5
# Jul 30      5
# Aug 14      5
# Jun 6       5
# Jul 23      5
# Jul 3       5
# Jun 27      5
# Jul 5       5
# May 24      4
# Jul 26      4
# Aug 17      4
# Jul 6       4
# Aug 15      4
# Jul 27      3
# Jul 25      3
# May 10      3
# Jul 9       3
# Jun 8       2
# June 4      1
# Name: Dates, dtype: int64

# %%
print(df_time_lun.Dates.value_counts())
# Out:
# Jun 7      8
# Jun 1      7
# Aug 10     7
# May 4      7
# May 18     7
# May 16     7
# Jul 2      6
# Jun 29     6
# Jul 31     6
# May 7      6
# Aug 13     6
# May 23     6
# Jul 13     6
# Jun 20     6
# Jul 24     6
# May 9      6
# Jun 27     5
# June 4     5
# Jun 28     5
# Jun 21     5
# Aug 9      5
# May 10     5
# May 15     5
# Jun 22     5
# May 22     5
# May 8      5
# May 31     5
# Aug 14     4
# May 14     4
# Jul 23     4
# May 17     4
# Aug 16     4
# Jun 6      4
# Jul 11     4
# Aug 21     4
# June 19    4
# May 21     4
# Jul 10     3
# Aug 15     3
# Jul 25     3
# Jul 3      3
# Jul 9      3
# Jul 26     3
# May 25     3
# May 11     3
# Jul 6      2
# Aug 17     2
# May 24     2
# Aug 20     2
# June 26    2
# Jun 5      2
# Jul 12     1
# Jul 30     1
# Name: Dates, dtype: int64

# %%
print(df_time_aft.Dates.value_counts())
# Out:
# Jul 12     14
# Jul 9      12
# May 14     11
# Jul 10     11
# Jul 11     10
# Aug 10     10
# Jun 22     10
# Jul 25     10
# Jul 13     10
# Aug 14     10
# Jun 20      9
# May 23      9
# Jun 21      9
# June 26     9
# Jul 26      8
# May 9       8
# Jun 6       8
# May 21      8
# Jun 27      8
# Aug 16      8
# Aug 21      8
# Jul 24      8
# May 31      7
# June 19     7
# Jul 31      7
# Jul 30      7
# Aug 9       7
# May 18      7
# May 22      7
# Jul 23      6
# May 24      6
# Aug 20      6
# May 17      6
# Jun 28      6
# Aug 13      6
# Jul 3       6
# Jun 1       5
# May 16      5
# Jul 2       5
# May 4       5
# May 11      5
# June 4      4
# May 15      4
# May 7       4
# May 10      4
# May 25      4
# Aug 15      4
# Jun 29      3
# Name: Dates, dtype: int64

# %%
#df_time_mor = df_uber_clean.query('Time < 1000') print(df_time_mor.groupby(['WkDay'], as_index = False)['Wages'].mean())
print(df_time_mor.query('Wages < 10.0').Wages.mean())
print(df_time_mor.query('Wages > 10.0').Wages.mean())
print(df_time_lun.query('Wages < 10.0').Wages.mean())
print(df_time_lun.query('Wages > 10.0').Wages.mean())
print(df_time_aft.query('Wages < 10.0').Wages.mean())
print(df_time_aft.query('Wages > 10.0').Wages.mean())
# Out:
# 5.3780402010050254
# 17.176479999999998
# 5.056258992805758
# 17.54175257731959
# 4.9649726775956315
# 16.312440476190478

# %%
mor_early_less = df_time_mor.query('Wages < 10.0 & Time < 900').Wages.mean()
print("Wages less than $10 and earned before 9:00 = {}".format(mor_early_less))
mor_early_more = df_time_mor.query('Wages >= 10.0 & Time < 900').Wages.mean()
print("Wages $10 or greater and earned before 9:00 = {}".format(mor_early_more))
mor_late_less = df_time_mor.query('Wages < 10.0 & Time > 900').Wages.mean()
print("Wages less than $10 and earned after 9:00 = {}".format(mor_late_less))
mor_late_more = df_time_mor.query('Wages > 10.0 & Time > 900').Wages.mean()
print("Wages $10 or greater and earned after 9:00 = {}".format(mor_late_more))
#print(df_time_lun.query('Wages < 10.0 & Time < 1200').Wages.mean())
#print(df_time_lun.query('Wages > 10.0 & Time < 1200').Wages.mean())
#print(df_time_lun.query('Wages < 10.0 & Time > 1200').Wages.mean())
#print(df_time_lun.query('Wages > 10.0 & Time > 1200').Wages.mean())
#print(df_time_aft.query('Wages < 10.0 & Time < 1600').Wages.mean())
#print(df_time_aft.query('Wages > 10.0 & Time < 1600').Wages.mean())
#print(df_time_aft.query('Wages < 10.0 & Time > 1600').Wages.mean())
#print(df_time_aft.query('Wages > 10.0 & Time > 1600').Wages.mean())
# Out:
# Wages less than $10 and earned before 9:00 = 5.432808219178085
# Wages $10 or greater and earned before 9:00 = 17.205113636363635
# Wages less than $10 and earned after 9:00 = 5.281568627450978
# Wages $10 or greater and earned after 9:00 = 17.108378378378383

# %%
#print(df_time_mor.query('Wages < 10.0 & Time < 900').Wages.value_counts())
